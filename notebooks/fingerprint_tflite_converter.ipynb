# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 20.5 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86

# %%
# !pip install opencv-python numpy
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.5.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 1.4 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.4 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 79.4 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 114.8 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 105.9 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 112.3 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 16.0 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wheel, werkzeug, tensorflow-io-gcs-filesystem, tensorboard-data-server, google-pasta, tensorboard, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-25.2.10 google-pasta-0.2.0 libclang-18.1.1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 werkzeug-3.1.3 wheel-0.45.1

# %%
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from keras.models import Model
from tensorflow.keras.layers import Lambda, Flatten, Dense

# %%
def conv2d_bn(x,
              layer=None,
              cv1_out=None,
              cv1_filter=(1, 1),
              cv1_strides=(1, 1),
              cv2_out=None,
              cv2_filter=(3, 3),
              cv2_strides=(1, 1),
              padding=None):
    num = '' if cv2_out == None else '1'
    tensor = Conv2D(cv1_out, cv1_filter, strides=cv1_strides, data_format='channels_last', name=layer+'_conv'+num)(x)
    tensor = BatchNormalization(axis=1, epsilon=0.00001, name=layer+'_bn'+num)(tensor)
    tensor = Activation('relu')(tensor)
    if padding == None:
        return tensor
    tensor = ZeroPadding2D(padding=padding, data_format='channels_last')(tensor)
    if cv2_out == None:
        return tensor
    tensor = Conv2D(cv2_out, cv2_filter, strides=cv2_strides, data_format='channels_last', name=layer+'_conv'+'2')(tensor)
    tensor = BatchNormalization(axis=1, epsilon=0.00001, name=layer+'_bn'+'2')(tensor)
    tensor = Activation('relu')(tensor)
    return tensor

def inception_block_1a(X):
    """
    Implementation of an inception block
    """

    X_3x3 = Conv2D(96, (1, 1), data_format='channels_last', name ='inception_3a_3x3_conv1')(X)
    X_3x3 = BatchNormalization(axis=1, epsilon=0.00001, name = 'inception_3a_3x3_bn1')(X_3x3)
    X_3x3 = Activation('relu')(X_3x3)
    X_3x3 = ZeroPadding2D(padding=(1, 1), data_format='channels_last')(X_3x3)
    X_3x3 = Conv2D(128, (3, 3), data_format='channels_last', name='inception_3a_3x3_conv2')(X_3x3)
    X_3x3 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3a_3x3_bn2')(X_3x3)
    X_3x3 = Activation('relu')(X_3x3)
    print(X_3x3.shape)

    X_5x5 = Conv2D(16, (1, 1), data_format='channels_last', name='inception_3a_5x5_conv1')(X)
    X_5x5 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3a_5x5_bn1')(X_5x5)
    X_5x5 = Activation('relu')(X_5x5)
    X_5x5 = ZeroPadding2D(padding=(2, 2), data_format='channels_last')(X_5x5)
    X_5x5 = Conv2D(32, (5, 5), data_format='channels_last', name='inception_3a_5x5_conv2')(X_5x5)
    X_5x5 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3a_5x5_bn2')(X_5x5)
    X_5x5 = Activation('relu')(X_5x5)
    print(X_5x5.shape)

    X_pool = MaxPooling2D(pool_size=3, strides=2, data_format='channels_last')(X)
    X_pool = Conv2D(32, (1, 1), data_format='channels_last', name='inception_3a_pool_conv')(X_pool)
    X_pool = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3a_pool_bn')(X_pool)
    X_pool = Activation('relu')(X_pool)
    X_pool = ZeroPadding2D(padding=((3, 4), (3, 4)), data_format='channels_last')(X_pool)
    print(X_pool.shape)

    X_1x1 = Conv2D(64, (1, 1), data_format='channels_last', name='inception_3a_1x1_conv')(X)
    X_1x1 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3a_1x1_bn')(X_1x1)
    X_1x1 = Activation('relu')(X_1x1)
    print(X_1x1.shape)

    # CONCAT
    inception = concatenate([X_3x3, X_5x5, X_pool, X_1x1], axis=-1)

    return inception


def inception_block_1b(X):
    X_3x3 = Conv2D(96, (1, 1), data_format='channels_last', name='inception_3b_3x3_conv1')(X)
    X_3x3 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3b_3x3_bn1')(X_3x3)
    X_3x3 = Activation('relu')(X_3x3)
    X_3x3 = ZeroPadding2D(padding=(1, 1), data_format='channels_last')(X_3x3)
    X_3x3 = Conv2D(128, (3, 3), data_format='channels_last', name='inception_3b_3x3_conv2')(X_3x3)
    X_3x3 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3b_3x3_bn2')(X_3x3)
    X_3x3 = Activation('relu')(X_3x3)

    X_5x5 = Conv2D(32, (1, 1), data_format='channels_last', name='inception_3b_5x5_conv1')(X)
    X_5x5 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3b_5x5_bn1')(X_5x5)
    X_5x5 = Activation('relu')(X_5x5)
    X_5x5 = ZeroPadding2D(padding=(2, 2), data_format='channels_last')(X_5x5)
    X_5x5 = Conv2D(64, (5, 5), data_format='channels_last', name='inception_3b_5x5_conv2')(X_5x5)
    X_5x5 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3b_5x5_bn2')(X_5x5)
    X_5x5 = Activation('relu')(X_5x5)

    X_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3), data_format='channels_last')(X)
    X_pool = Conv2D(64, (1, 1), data_format='channels_last', name='inception_3b_pool_conv')(X_pool)
    X_pool = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3b_pool_bn')(X_pool)
    X_pool = Activation('relu')(X_pool)
    X_pool = ZeroPadding2D(padding=(4, 4), data_format='channels_last')(X_pool)

    X_1x1 = Conv2D(64, (1, 1), data_format='channels_last', name='inception_3b_1x1_conv')(X)
    X_1x1 = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3b_1x1_bn')(X_1x1)
    X_1x1 = Activation('relu')(X_1x1)

    inception = concatenate([X_3x3, X_5x5, X_pool, X_1x1], axis=-1)

    return inception

def inception_block_1c(X):
    X_3x3 = conv2d_bn(X,
                           layer='inception_3c_3x3',
                           cv1_out=128,
                           cv1_filter=(1, 1),
                           cv2_out=256,
                           cv2_filter=(3, 3),
                           cv2_strides=(2, 2),
                           padding=(1, 1))

    X_5x5 = conv2d_bn(X,
                           layer='inception_3c_5x5',
                           cv1_out=32,
                           cv1_filter=(1, 1),
                           cv2_out=64,
                           cv2_filter=(5, 5),
                           cv2_strides=(2, 2),
                           padding=(2, 2))

    X_pool = MaxPooling2D(pool_size=3, strides=2, data_format='channels_last')(X)
    X_pool = ZeroPadding2D(padding=((0, 1), (0, 1)), data_format='channels_last')(X_pool)

    inception = concatenate([X_3x3, X_5x5, X_pool], axis=-1)

    return inception

def inception_block_2a(X):
    X_3x3 = conv2d_bn(X,
                           layer='inception_4a_3x3',
                           cv1_out=96,
                           cv1_filter=(1, 1),
                           cv2_out=192,
                           cv2_filter=(3, 3),
                           cv2_strides=(1, 1),
                           padding=(1, 1))
    X_5x5 = conv2d_bn(X,
                           layer='inception_4a_5x5',
                           cv1_out=32,
                           cv1_filter=(1, 1),
                           cv2_out=64,
                           cv2_filter=(5, 5),
                           cv2_strides=(1, 1),
                           padding=(2, 2))

    X_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3), data_format='channels_last')(X)
    X_pool = conv2d_bn(X_pool,
                           layer='inception_4a_pool',
                           cv1_out=128,
                           cv1_filter=(1, 1),
                           padding=(2, 2))
    X_1x1 = conv2d_bn(X,
                           layer='inception_4a_1x1',
                           cv1_out=256,
                           cv1_filter=(1, 1))
    inception = concatenate([X_3x3, X_5x5, X_pool, X_1x1], axis=-1)

    return inception

def inception_block_2b(X):
    #inception4e
    X_3x3 = conv2d_bn(X,
                           layer='inception_4e_3x3',
                           cv1_out=160,
                           cv1_filter=(1, 1),
                           cv2_out=256,
                           cv2_filter=(3, 3),
                           cv2_strides=(2, 2),
                           padding=(1, 1))
    X_5x5 = conv2d_bn(X,
                           layer='inception_4e_5x5',
                           cv1_out=64,
                           cv1_filter=(1, 1),
                           cv2_out=128,
                           cv2_filter=(5, 5),
                           cv2_strides=(2, 2),
                           padding=(2, 2))

    X_pool = MaxPooling2D(pool_size=3, strides=2, data_format='channels_last')(X)
    X_pool = ZeroPadding2D(padding=((0, 1), (0, 1)), data_format='channels_last')(X_pool)

    inception = concatenate([X_3x3, X_5x5, X_pool], axis=-1)

    return inception

def inception_block_3a(X):
    X_3x3 = conv2d_bn(X,
                           layer='inception_5a_3x3',
                           cv1_out=96,
                           cv1_filter=(1, 1),
                           cv2_out=384,
                           cv2_filter=(3, 3),
                           cv2_strides=(1, 1),
                           padding=(1, 1))
    X_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3), data_format='channels_last')(X)
    X_pool = conv2d_bn(X_pool,
                           layer='inception_5a_pool',
                           cv1_out=96,
                           cv1_filter=(1, 1),
                           padding=(1, 1))
    X_1x1 = conv2d_bn(X,
                           layer='inception_5a_1x1',
                           cv1_out=256,
                           cv1_filter=(1, 1))

    inception = concatenate([X_3x3, X_pool, X_1x1], axis=-1)

    return inception

def inception_block_3b(X):
    X_3x3 = conv2d_bn(X,
                           layer='inception_5b_3x3',
                           cv1_out=96,
                           cv1_filter=(1, 1),
                           cv2_out=384,
                           cv2_filter=(3, 3),
                           cv2_strides=(1, 1),
                           padding=(1, 1))
    X_pool = MaxPooling2D(pool_size=3, strides=2, data_format='channels_last')(X)
    X_pool = conv2d_bn(X_pool,
                           layer='inception_5b_pool',
                           cv1_out=96,
                           cv1_filter=(1, 1))
    X_pool = ZeroPadding2D(padding=(1, 1), data_format='channels_last')(X_pool)

    X_1x1 = conv2d_bn(X,
                           layer='inception_5b_1x1',
                           cv1_out=256,
                           cv1_filter=(1, 1))
    inception = concatenate([X_3x3, X_pool, X_1x1], axis=-1)

    return inception

def imgRecoModel(input_shape):
    """
    Implementation of the Inception model used for FaceNet

    Arguments:
    input_shape -- shape of the images of the dataset
    Returns:
    model -- a Model() instance in Keras
    """

    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)

    # First Block
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1')(X)
    X = BatchNormalization(axis = -1, name = 'bn1')(X)
    X = Activation('relu')(X)

    # Zero-Padding + MAXPOOL
    X = ZeroPadding2D((1, 1))(X)
    X = MaxPooling2D((3, 3), strides = 2)(X)

    # Second Block
    X = Conv2D(64, (1, 1), strides = (1, 1), name = 'conv2')(X)
    X = BatchNormalization(axis = -1, epsilon=0.00001, name = 'bn2')(X)
    X = Activation('relu')(X)

    # Zero-Padding + MAXPOOL
    X = ZeroPadding2D((1, 1))(X)

    # Second Block
    X = Conv2D(192, (3, 3), strides = (1, 1), name = 'conv3')(X)
    X = BatchNormalization(axis = -1, epsilon=0.00001, name = 'bn3')(X)
    X = Activation('relu')(X)

    # Zero-Padding + MAXPOOL
    X = ZeroPadding2D((1, 1))(X)
    X = MaxPooling2D(pool_size = 3, strides = 2)(X)

    # Inception 1: a/b/c
    X = inception_block_1a(X)
    X = inception_block_1b(X)
    X = inception_block_1c(X)

    # Inception 2: a/b
    X = inception_block_2a(X)
    X = inception_block_2b(X)

    # Inception 3: a/b
    X = inception_block_3a(X)
    X = inception_block_3b(X)

    # Top layer
    X = AveragePooling2D(pool_size=(3, 3), strides=(1, 1), data_format='channels_last')(X)
    X = Flatten()(X)
    X = Dense(128, name='dense_layer')(X)

    # L2 normalization
    # Changed from K.l2_normalize to tf.math.l2_normalize
    X = Lambda(lambda  x: tf.math.l2_normalize(x,axis=1), output_shape=(128,))(X)

    # Create model instance
    model = Model(inputs = X_input, outputs = X, name='ImgRecoModel')

    return model

# %%
from keras.layers import Input
from keras.models import Model
from keras import backend as K
K.set_image_data_format('channels_last')
import tensorflow as tf

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def euclidean_distance(vects):
  x, y = vects
  sum_square = tf.reduce_sum(tf.square(x - y), axis=1, keepdims=True)
  return tf.sqrt(tf.maximum(sum_square, tf.keras.backend.epsilon())) # Changed from K.sqrt and K.maximum to tf.sqrt and tf.maximum

def euc_dist_out_shape(shapes):
  shape1, shape2 = shapes
  return (shape1[0], 1)

def build_network(network, input_shape):
  f_inp = Input(input_shape, name='first_input')
  s_inp = Input(input_shape, name='second_input')

  f_enc = network(f_inp)
  s_enc = network(s_inp)

  output_layer = Lambda(euclidean_distance, output_shape=euc_dist_out_shape)([f_enc, s_enc])
  model = Model(inputs=[f_inp, s_inp], outputs=output_layer)
  return model

# %%
def contrastive_loss_with_margin(margin):
  def contrastive_loss(y_true, y_pred):
    square_pred = tf.square(y_pred)
    margin_square = tf.square(tf.maximum(margin - y_pred, 0))
    return tf.reduce_mean(y_true * square_pred + (1 - y_true) * margin_square)
  return contrastive_loss

# %%
input_shape = (96, 96, 1)
network = imgRecoModel(input_shape)
network.load_weights("/content/model_siamese_net1_r.h5")
# Out:
# (None, 12, 12, 128)
# (None, 12, 12, 32)
# (None, 12, 12, 32)
# (None, 12, 12, 64)

# %%
network.export("siamese_saved_model")  
# Convert SavedModel to TFLite
converter = tf.lite.TFLiteConverter.from_saved_model("siamese_saved_model")
tflite_model = converter.convert()

with open("siamese_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# Saved artifact at 'siamese_saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 1), dtype=tf.float32, name='keras_tensor_483')
# Output Type:
#   TensorSpec(shape=(None, 128), dtype=tf.float32, name=None)
# Captures:
#   138289564439504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564446224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564446416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564445648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564443728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564446032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564447952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564448528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564448720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564447568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564434704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564448336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564450256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564450448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564450640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564449104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289564446800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760852240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760852816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760847632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760848208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760851856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760846288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760852624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760848400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760847248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760846864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760848016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760856848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760857424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760859152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760859728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760857616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760856464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760851088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760857232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760854544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760855120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760850512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760859920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760858768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760853392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760859536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760855312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760854160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760854928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760850704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760849552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760845904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762324304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762324880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760861456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760861840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762325072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762323920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762321616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762324688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760860688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762320848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760860304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289760862032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762328912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762329488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762331216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762331792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762329680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762328528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762323152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762329296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762326608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762327184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762322000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762322576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762331984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762330832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762325456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762331600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762327376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762326224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762321424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762326992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762322768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762320656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762321232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762322384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762633104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762633680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762333520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762334096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762633872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762632528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762631952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762633488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762334288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762333136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762327760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762333904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762635408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762635984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762335824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762336400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762636176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762635024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762632720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762635792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762335056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762334672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762330064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762335440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762642320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762642896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762637712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762638288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762643088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762641936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762636560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762642704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762638480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762637328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762631760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762638096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762646928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762647504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562960144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562961680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762645776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762643472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762641168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762646544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762644624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762645200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762640016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762640592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562961872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562961104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562960336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562961488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762645392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762644240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762638864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762645008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762640784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762639632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762634256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289762640400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562968016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562968592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562963408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562963984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562968784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562967632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562962256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562968400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562964176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562963024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562960720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562963792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562970320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562970896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562965712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562966288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562971088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562969936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562964560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562970704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562966480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562965328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562960912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562966096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562972624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562973200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562973392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562972240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562966864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562973008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562971472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563338320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563340048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563340624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563338512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563337744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563336976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563338128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562974928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562975504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563340816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563339664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563337360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563340432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562976080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562974160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562969168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289562975312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563342352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563342928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563343120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563341968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563336784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563342736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563346960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563347536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563349264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563349840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563347728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563346576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563341200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563347344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563344656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563345232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563350032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563348880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563343504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563349648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563345424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563344272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563338896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563345040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563351568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138289563352144: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
network.summary()
# Out:
# Model: "ImgRecoModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 96, 96, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_23   │ (None, 102, 102,  │          0 │ input_layer_1[0]… │
# │ (ZeroPadding2D)     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1 (Conv2D)      │ (None, 48, 48,    │      3,200 │ zero_padding2d_2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1                 │ (None, 48, 48,    │        256 │ conv1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 48, 48,    │          0 │ bn1[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_24   │ (None, 50, 50,    │          0 │ activation_37[0]… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 24, 24,    │          0 │ zero_padding2d_2… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2 (Conv2D)      │ (None, 24, 24,    │      4,160 │ max_pooling2d_6[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn2                 │ (None, 24, 24,    │        256 │ conv2[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 24, 24,    │          0 │ bn2[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_25   │ (None, 26, 26,    │          0 │ activation_38[0]… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3 (Conv2D)      │ (None, 24, 24,    │    110,784 │ zero_padding2d_2… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn3                 │ (None, 24, 24,    │        768 │ conv3[0][0]       │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 24, 24,    │          0 │ bn3[0][0]         │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_26   │ (None, 26, 26,    │          0 │ activation_39[0]… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 12, 12,    │          0 │ zero_padding2d_2… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3_c… │ (None, 12, 12,    │     18,528 │ max_pooling2d_7[… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5_c… │ (None, 12, 12,    │      3,088 │ max_pooling2d_7[… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3_b… │ (None, 12, 12,    │         48 │ inception_3a_3x3… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5_b… │ (None, 12, 12,    │         48 │ inception_3a_5x5… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 12, 12,    │          0 │ inception_3a_3x3… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 12, 12,    │          0 │ inception_3a_5x5… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 5, 5, 192) │          0 │ max_pooling2d_7[… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_27   │ (None, 14, 14,    │          0 │ activation_40[0]… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_28   │ (None, 16, 16,    │          0 │ activation_42[0]… │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool_… │ (None, 5, 5, 32)  │      6,176 │ max_pooling2d_8[… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3_c… │ (None, 12, 12,    │    110,720 │ zero_padding2d_2… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5_c… │ (None, 12, 12,    │     12,832 │ zero_padding2d_2… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_pool_… │ (None, 5, 5, 32)  │         20 │ inception_3a_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_1x1_c… │ (None, 12, 12,    │     12,352 │ max_pooling2d_7[… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_3x3_b… │ (None, 12, 12,    │         48 │ inception_3a_3x3… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_5x5_b… │ (None, 12, 12,    │         48 │ inception_3a_5x5… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 5, 5, 32)  │          0 │ inception_3a_poo… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a_1x1_bn │ (None, 12, 12,    │         48 │ inception_3a_1x1… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 12, 12,    │          0 │ inception_3a_3x3… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 12, 12,    │          0 │ inception_3a_5x5… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_29   │ (None, 12, 12,    │          0 │ activation_44[0]… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 12, 12,    │          0 │ inception_3a_1x1… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 12, 12,    │          0 │ activation_41[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_43[0]… │
# │                     │                   │            │ zero_padding2d_2… │
# │                     │                   │            │ activation_45[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3_c… │ (None, 12, 12,    │     24,672 │ concatenate_7[0]… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5_c… │ (None, 12, 12,    │      8,224 │ concatenate_7[0]… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3_b… │ (None, 12, 12,    │         48 │ inception_3b_3x3… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5_b… │ (None, 12, 12,    │         48 │ inception_3b_5x5… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 12, 12,    │          0 │ inception_3b_3x3… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 12, 12,    │          0 │ inception_3b_5x5… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_4 │ (None, 4, 4, 256) │          0 │ concatenate_7[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_30   │ (None, 14, 14,    │          0 │ activation_46[0]… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_31   │ (None, 16, 16,    │          0 │ activation_48[0]… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool_… │ (None, 4, 4, 64)  │     16,448 │ average_pooling2… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3_c… │ (None, 12, 12,    │    110,720 │ zero_padding2d_3… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5_c… │ (None, 12, 12,    │     51,264 │ zero_padding2d_3… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_pool_… │ (None, 4, 4, 64)  │         16 │ inception_3b_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_1x1_c… │ (None, 12, 12,    │     16,448 │ concatenate_7[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_3x3_b… │ (None, 12, 12,    │         48 │ inception_3b_3x3… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_5x5_b… │ (None, 12, 12,    │         48 │ inception_3b_5x5… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 4, 4, 64)  │          0 │ inception_3b_poo… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b_1x1_bn │ (None, 12, 12,    │         48 │ inception_3b_1x1… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 12, 12,    │          0 │ inception_3b_3x3… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 12, 12,    │          0 │ inception_3b_5x5… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_32   │ (None, 12, 12,    │          0 │ activation_50[0]… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 12, 12,    │          0 │ inception_3b_1x1… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 12, 12,    │          0 │ activation_47[0]… │
# │ (Concatenate)       │ 320)              │            │ activation_49[0]… │
# │                     │                   │            │ zero_padding2d_3… │
# │                     │                   │            │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3c_3x3_c… │ (None, 12, 12,    │     41,088 │ concatenate_8[0]… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3c_5x5_c… │ (None, 12, 12,    │     10,272 │ concatenate_8[0]… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3c_3x3_b… │ (None, 12, 12,    │         48 │ inception_3c_3x3… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3c_5x5_b… │ (None, 12, 12,    │         48 │ inception_3c_5x5… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 12, 12,    │          0 │ inception_3c_3x3… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 12, 12,    │          0 │ inception_3c_5x5… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_33   │ (None, 14, 14,    │          0 │ activation_52[0]… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_34   │ (None, 16, 16,    │          0 │ activation_54[0]… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3c_3x3_c… │ (None, 6, 6, 256) │    295,168 │ zero_padding2d_3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3c_5x5_c… │ (None, 6, 6, 64)  │     51,264 │ zero_padding2d_3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3c_3x3_b… │ (None, 6, 6, 256) │         24 │ inception_3c_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3c_5x5_b… │ (None, 6, 6, 64)  │         24 │ inception_3c_5x5… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 5, 5, 320) │          0 │ concatenate_8[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 6, 6, 256) │          0 │ inception_3c_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 6, 6, 64)  │          0 │ inception_3c_5x5… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_35   │ (None, 6, 6, 320) │          0 │ max_pooling2d_9[… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 6, 6, 640) │          0 │ activation_53[0]… │
# │ (Concatenate)       │                   │            │ activation_55[0]… │
# │                     │                   │            │ zero_padding2d_3… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3_c… │ (None, 6, 6, 96)  │     61,536 │ concatenate_9[0]… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5_c… │ (None, 6, 6, 32)  │     20,512 │ concatenate_9[0]… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3_b… │ (None, 6, 6, 96)  │         24 │ inception_4a_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5_b… │ (None, 6, 6, 32)  │         24 │ inception_4a_5x5… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 6, 6, 96)  │          0 │ inception_4a_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 6, 6, 32)  │          0 │ inception_4a_5x5… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_5 │ (None, 2, 2, 640) │          0 │ concatenate_9[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_36   │ (None, 8, 8, 96)  │          0 │ activation_56[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_37   │ (None, 10, 10,    │          0 │ activation_58[0]… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool_… │ (None, 2, 2, 128) │     82,048 │ average_pooling2… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3_c… │ (None, 6, 6, 192) │    166,080 │ zero_padding2d_3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5_c… │ (None, 6, 6, 64)  │     51,264 │ zero_padding2d_3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_pool_… │ (None, 2, 2, 128) │          8 │ inception_4a_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_1x1_c… │ (None, 6, 6, 256) │    164,096 │ concatenate_9[0]… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_3x3_b… │ (None, 6, 6, 192) │         24 │ inception_4a_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_5x5_b… │ (None, 6, 6, 64)  │         24 │ inception_4a_5x5… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_60       │ (None, 2, 2, 128) │          0 │ inception_4a_poo… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a_1x1_bn │ (None, 6, 6, 256) │         24 │ inception_4a_1x1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 6, 6, 192) │          0 │ inception_4a_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 6, 6, 64)  │          0 │ inception_4a_5x5… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_38   │ (None, 6, 6, 128) │          0 │ activation_60[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_61       │ (None, 6, 6, 256) │          0 │ inception_4a_1x1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 6, 6, 640) │          0 │ activation_57[0]… │
# │ (Concatenate)       │                   │            │ activation_59[0]… │
# │                     │                   │            │ zero_padding2d_3… │
# │                     │                   │            │ activation_61[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3_c… │ (None, 6, 6, 160) │    102,560 │ concatenate_10[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5_c… │ (None, 6, 6, 64)  │     41,024 │ concatenate_10[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3_b… │ (None, 6, 6, 160) │         24 │ inception_4e_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5_b… │ (None, 6, 6, 64)  │         24 │ inception_4e_5x5… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_62       │ (None, 6, 6, 160) │          0 │ inception_4e_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_64       │ (None, 6, 6, 64)  │          0 │ inception_4e_5x5… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_39   │ (None, 8, 8, 160) │          0 │ activation_62[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_40   │ (None, 10, 10,    │          0 │ activation_64[0]… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3_c… │ (None, 3, 3, 256) │    368,896 │ zero_padding2d_3… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5_c… │ (None, 3, 3, 128) │    204,928 │ zero_padding2d_4… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_3x3_b… │ (None, 3, 3, 256) │         12 │ inception_4e_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e_5x5_b… │ (None, 3, 3, 128) │         12 │ inception_4e_5x5… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 2, 2, 640) │          0 │ concatenate_10[0… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_63       │ (None, 3, 3, 256) │          0 │ inception_4e_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_65       │ (None, 3, 3, 128) │          0 │ inception_4e_5x5… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_41   │ (None, 3, 3, 640) │          0 │ max_pooling2d_10… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 3, 3,      │          0 │ activation_63[0]… │
# │ (Concatenate)       │ 1024)             │            │ activation_65[0]… │
# │                     │                   │            │ zero_padding2d_4… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3_c… │ (None, 3, 3, 96)  │     98,400 │ concatenate_11[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3_b… │ (None, 3, 3, 96)  │         12 │ inception_5a_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_66       │ (None, 3, 3, 96)  │          0 │ inception_5a_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_6 │ (None, 1, 1,      │          0 │ concatenate_11[0… │
# │ (AveragePooling2D)  │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_42   │ (None, 5, 5, 96)  │          0 │ activation_66[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool_… │ (None, 1, 1, 96)  │     98,400 │ average_pooling2… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3_c… │ (None, 3, 3, 384) │    332,160 │ zero_padding2d_4… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_pool_… │ (None, 1, 1, 96)  │          4 │ inception_5a_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_1x1_c… │ (None, 3, 3, 256) │    262,400 │ concatenate_11[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_3x3_b… │ (None, 3, 3, 384) │         12 │ inception_5a_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_68       │ (None, 1, 1, 96)  │          0 │ inception_5a_poo… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a_1x1_bn │ (None, 3, 3, 256) │         12 │ inception_5a_1x1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_67       │ (None, 3, 3, 384) │          0 │ inception_5a_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_43   │ (None, 3, 3, 96)  │          0 │ activation_68[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_69       │ (None, 3, 3, 256) │          0 │ inception_5a_1x1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 3, 3, 736) │          0 │ activation_67[0]… │
# │ (Concatenate)       │                   │            │ zero_padding2d_4… │
# │                     │                   │            │ activation_69[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3_c… │ (None, 3, 3, 96)  │     70,752 │ concatenate_12[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3_b… │ (None, 3, 3, 96)  │         12 │ inception_5b_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_70       │ (None, 3, 3, 96)  │          0 │ inception_5b_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 1, 1, 736) │          0 │ concatenate_12[0… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_44   │ (None, 5, 5, 96)  │          0 │ activation_70[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool_… │ (None, 1, 1, 96)  │     70,752 │ max_pooling2d_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3_c… │ (None, 3, 3, 384) │    332,160 │ zero_padding2d_4… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_pool_… │ (None, 1, 1, 96)  │          4 │ inception_5b_poo… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_1x1_c… │ (None, 3, 3, 256) │    188,672 │ concatenate_12[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_3x3_b… │ (None, 3, 3, 384) │         12 │ inception_5b_3x3… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_72       │ (None, 1, 1, 96)  │          0 │ inception_5b_poo… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b_1x1_bn │ (None, 3, 3, 256) │         12 │ inception_5b_1x1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_71       │ (None, 3, 3, 384) │          0 │ inception_5b_3x3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_45   │ (None, 3, 3, 96)  │          0 │ activation_72[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_73       │ (None, 3, 3, 256) │          0 │ inception_5b_1x1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 3, 3, 736) │          0 │ activation_71[0]… │
# │ (Concatenate)       │                   │            │ zero_padding2d_4… │
# │                     │                   │            │ activation_73[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_7 │ (None, 1, 1, 736) │          0 │ concatenate_13[0… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 736)       │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_layer (Dense) │ (None, 128)       │     94,336 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 128)       │          0 │ dense_layer[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,720,604 (14.19 MB)
#  Trainable params: 3,719,494 (14.19 MB)
#  Non-trainable params: 1,110 (4.34 KB)
